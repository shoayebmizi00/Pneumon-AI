# %% [markdown]
# # One-time final evaluation
# Run only after model selection and threshold calibration are complete. The script refuses to overwrite an existing final test report unless explicitly forced.

# %%
# Run from the repository root exactly once:
# python -m training.evaluate
from pathlib import Path
print('Final model ready:', Path('../models/best_pneumonia_model.pth').exists())
print('Test report exists:', Path('../results/test_metrics.json').exists())
