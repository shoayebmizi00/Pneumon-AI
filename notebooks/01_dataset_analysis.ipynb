# %% [markdown]
# # Dataset audit
# Runs the repository audit that verifies decoding, dimensions, image modes, exact duplicates, class balance, and patient overlap.

# %%
from training.audit import audit_dataset
summary = audit_dataset('../pneumonia_dataset/chest_xray', '../results')
summary
