# %% [markdown]
# # Model training and validation selection
# The canonical, reproducible entry point is `training.train`. It never loads the test partition.

# %%
# Run from the repository root:
# python -m training.train --models baseline densenet121 efficientnet_b0 resnet50 mobilenet_v3
from training.config import ExperimentConfig
ExperimentConfig().to_dict()
